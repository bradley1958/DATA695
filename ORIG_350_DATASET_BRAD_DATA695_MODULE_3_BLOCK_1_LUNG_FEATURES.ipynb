# %%
# Let's load pandas and see the first few rows of the dataset for COVID-19 project.
import pandas as pd
import os
import sys
covid = pd.read_csv('https://raw.githubusercontent.com/bradley1958/DATA695/master/BRAD_REVISED_COVID_DATASET.csv')
covid.head()
# Out:
#   PATIENT ID  GENDER BINARY  ... SORE THROAT BINARY  SORE THROAT YES/NO
# 0         P1              1  ...                  0                  No
# 1         P2              1  ...                  0                  No
# 2         P3              1  ...                  0                  No
# 3         P4              1  ...                  1                 Yes
# 4         P5              1  ...                  1                 Yes
#
# [5 rows x 56 columns]

# %% [markdown]
# This is our revised CoVid-19 Dataset with revised Column Headings

# %% [markdown]
# Next, let's look at the structure of our COVID Dataset.

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 56 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   PATIENT ID                                 350 non-null    object
#  1   GENDER BINARY                              350 non-null    int64
#  2   GENDER                                     350 non-null    object
#  3   AGE                                        350 non-null    int64
#  4   AGE 60 PLUS                                350 non-null    int64
#  5   60 PLUS YES/NO                             350 non-null    object
#  6   COVID TEST BINARY                          350 non-null    int64
#  7   COVID TEST RESULTS                         350 non-null    object
#  8   ONSET TO HOSP ADMIT DAYS                   350 non-null    int64
#  9   TRANSFER TO ICU IN DAYS                    350 non-null    int64
#  10  72HRS TO ICU                               350 non-null    object
#  11  72HRS TO ICU BINARY                        350 non-null    int64
#  12  ADMIT CRP LEVEL                            350 non-null    int64
#  13  ABNORMAL CRP YES/NO                        350 non-null    object
#  14  BLOOD CRP ABNORMAL                         350 non-null    int64
#  15  ADMIT ESR LEVEL                            350 non-null    int64
#  16  ABNORMAL ESR YES/NO                        350 non-null    object
#  17  BLOOD ESR ABNORMAL                         350 non-null    int64
#  18  ADMIT INR LEVEL                            350 non-null    float64
#  19  ABNORMAL INR YES/NO                        350 non-null    object
#  20  BLOOD INR ABNORMAL                         350 non-null    int64
#  21  ADMIT PT LEVEL                             350 non-null    float64
#  22  ABNORMAL PT YES/NO                         350 non-null    object
#  23  BLOOD PT ABNORMAL                          350 non-null    int64
#  24  ADMIT FIBRINOGEN                           350 non-null    float64
#  25  ABNORMAL FIBRINOGEN YES/NO                 350 non-null    object
#  26  BLOOD FIBRINOGEN ABNORMAL                  350 non-null    int64
#  27  ADMIT CHEST CT PERCENTAGE OBSTRUCTED       350 non-null    int64
#  28  ADMIT CHEST CT GREATER 25 PERCENT          350 non-null    object
#  29  CHEST CT GREATER 25 PERCENT BINARY         350 non-null    int64
#  30  VENTILATION BINARY                         350 non-null    int64
#  31  VENTILATION YES/NO                         350 non-null    object
#  32  LOSS SMELL TASTE BINARY                    350 non-null    int64
#  33  LOSS SMELL TASTE YES/NO                    350 non-null    object
#  34  ADMIT PLATELET COUNT                       350 non-null    int64
#  35  ABNORMAL PLATELET YES/NO                   350 non-null    object
#  36  BLOOD PLATELET ABNORMAL                    350 non-null    int64
#  37  CHEST CT PERCENT POST TREAT 7DAYS          350 non-null    int64
#  38  ABNORMAL CHEST CT POST TREAT 7DAYS BINARY  350 non-null    int64
#  39  CRP POST TREAT 7DAYS                       350 non-null    int64
#  40  COUGH BINARY                               350 non-null    int64
#  41  COUGH YES/NO                               350 non-null    object
#  42  DIARRHEA BINARY                            350 non-null    int64
#  43  DIARRHEA YES/NO                            350 non-null    object
#  44  ADMIT LABORED BREATHING BINARY             350 non-null    int64
#  45  DYSPNEA YES/NO                             350 non-null    object
#  46  SMOKER BINARY                              350 non-null    int64
#  47  SMOKER YES/NO                              350 non-null    object
#  48  PULSE OX BELOW 88                          350 non-null    int64
#  49  PULSE OX BELOW 88 YES/NO                   350 non-null    object
#  50  TEMP ABOVE 103 BINARY                      350 non-null    int64
#  51  TEMP ABOVE 103 YES/NO                      350 non-null    object
#  52  OBESE BINARY                               350 non-null    int64
#  53  OBESE YES/NO                               350 non-null    object
#  54  SORE THROAT BINARY                         350 non-null    int64
#  55  SORE THROAT YES/NO                         350 non-null    object
# dtypes: float64(3), int64(31), object(22)
# memory usage: 153.2+ KB

# %% [markdown]
# We see above that we have a dataset with 350 records by 55 columns. The dtypes are "float64" at 3, "int64" at 31, and "object" at 22. We also see that we have no "null" values to deal with. If we had missing values I would have taken the median value for each column heading containing "null' values and subsituted that column's median value for missing data points within a specific column. Next, let's pull some discriptive statistics about our data points.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.image as mpimg
import numpy as np
from sklearn import metrics
import scipy.stats as stats
from pandas import set_option
import pandas.util.testing as tm
plt.style.use('ggplot')

print("SUMMARY STATISTICS OF NUMERIC COLUMNS")
print()
print(covid.describe().T)
# Out:
# SUMMARY STATISTICS OF NUMERIC COLUMNS
#
#                                            count        mean  ...     75%     max
# GENDER BINARY                              350.0    0.577143  ...    1.00    1.00
# AGE                                        350.0   57.805714  ...   69.00   94.00
# AGE 60 PLUS                                350.0    0.460000  ...    1.00    1.00
# COVID TEST BINARY                          350.0    0.677143  ...    1.00    1.00
# ONSET TO HOSP ADMIT DAYS                   350.0    8.157143  ...   10.00   28.00
# TRANSFER TO ICU IN DAYS                    350.0    2.445714  ...    4.00   14.00
# 72HRS TO ICU BINARY                        350.0    0.754286  ...    1.00    1.00
# ADMIT CRP LEVEL                            350.0   95.091429  ...  155.00  328.00
# BLOOD CRP ABNORMAL                         350.0    0.948571  ...    1.00    1.00
# ADMIT ESR LEVEL                            350.0   40.711429  ...   57.75  158.00
# BLOOD ESR ABNORMAL                         350.0    0.648571  ...    1.00    1.00
# ADMIT INR LEVEL                            350.0    1.274714  ...    1.34    1.92
# BLOOD INR ABNORMAL                         350.0    0.662857  ...    1.00    1.00
# ADMIT PT LEVEL                             350.0   13.908171  ...   14.50   20.60
# BLOOD PT ABNORMAL                          350.0    0.485714  ...    1.00    1.00
# ADMIT FIBRINOGEN                           350.0    4.897000  ...    5.20   11.48
# BLOOD FIBRINOGEN ABNORMAL                  350.0    0.840000  ...    1.00    1.00
# ADMIT CHEST CT PERCENTAGE OBSTRUCTED       350.0   51.280000  ...   60.00   92.00
# CHEST CT GREATER 25 PERCENT BINARY         350.0    0.911429  ...    1.00    1.00
# VENTILATION BINARY                         350.0    0.645714  ...    1.00    1.00
# LOSS SMELL TASTE BINARY                    350.0    0.388571  ...    1.00    1.00
# ADMIT PLATELET COUNT                       350.0  181.397143  ...  217.50  493.00
# BLOOD PLATELET ABNORMAL                    350.0    0.360000  ...    1.00    1.00
# CHEST CT PERCENT POST TREAT 7DAYS          350.0   35.737143  ...   58.75  100.00
# ABNORMAL CHEST CT POST TREAT 7DAYS BINARY  350.0    0.545714  ...    1.00    1.00
# CRP POST TREAT 7DAYS                       350.0   63.942857  ...   65.00  323.00
# COUGH BINARY                               350.0    0.611429  ...    1.00    1.00
# DIARRHEA BINARY                            350.0    0.222857  ...    0.00    1.00
# ADMIT LABORED BREATHING BINARY             350.0    0.688571  ...    1.00    1.00
# SMOKER BINARY                              350.0    0.688571  ...    1.00    1.00
# PULSE OX BELOW 88                          350.0    0.848571  ...    1.00    1.00
# TEMP ABOVE 103 BINARY                      350.0    0.688571  ...    1.00    1.00
# OBESE BINARY                               350.0    0.691429  ...    1.00    1.00
# SORE THROAT BINARY                         350.0    0.691429  ...    1.00    1.00
#
# [34 rows x 8 columns]

# %% [markdown]
# From our descriptive statistics let's focus on the following columns: AGE, ONSET TO HOSP ADMIT DAYS, ADMIT CRP LEVEL, ADMIT ESR LEVEL, ADMIT INR LEVEL, ADMIT PT LEVEL, ADMIT FIBRINOGEN, ADMIT CHECT CT PERCENTAGE, ADMIT PLATELET COUNT, CHEST CT PERCENT POST TREAT 7DAYS, and CRP POST TREAT 7DAYS.  To do this I will take a slice from the master dataset.

# %%
stats_subset = covid[['AGE','ONSET TO HOSP ADMIT DAYS','TRANSFER TO ICU IN DAYS','ADMIT CRP LEVEL','ADMIT ESR LEVEL','ADMIT INR LEVEL','ADMIT PT LEVEL','ADMIT FIBRINOGEN','ADMIT CHEST CT PERCENTAGE OBSTRUCTED','ADMIT PLATELET COUNT','CHEST CT PERCENT POST TREAT 7DAYS','CRP POST TREAT 7DAYS']]
stats_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   AGE                                   350 non-null    int64
#  1   ONSET TO HOSP ADMIT DAYS              350 non-null    int64
#  2   TRANSFER TO ICU IN DAYS               350 non-null    int64
#  3   ADMIT CRP LEVEL                       350 non-null    int64
#  4   ADMIT ESR LEVEL                       350 non-null    int64
#  5   ADMIT INR LEVEL                       350 non-null    float64
#  6   ADMIT PT LEVEL                        350 non-null    float64
#  7   ADMIT FIBRINOGEN                      350 non-null    float64
#  8   ADMIT CHEST CT PERCENTAGE OBSTRUCTED  350 non-null    int64
#  9   ADMIT PLATELET COUNT                  350 non-null    int64
#  10  CHEST CT PERCENT POST TREAT 7DAYS     350 non-null    int64
#  11  CRP POST TREAT 7DAYS                  350 non-null    int64
# dtypes: float64(3), int64(9)
# memory usage: 32.9 KB

# %%
stats_subset.describe()
# Out:
#               AGE  ...  CRP POST TREAT 7DAYS
# count  350.000000  ...            350.000000
# mean    57.805714  ...             63.942857
# std     15.113779  ...             53.396362
# min     20.000000  ...              0.000000
# 25%     47.000000  ...             36.000000
# 50%     58.500000  ...             56.000000
# 75%     69.000000  ...             65.000000
# max     94.000000  ...            323.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# Here is the breakout of our discriptive statistics on numeric data features from our Covid Data subset:
#
# **Age**
#
# Min - 20 Yrs
#
# Max - 94 Yrs
#
# Mean - Nearly 58 Yrs
#
# **Time to Admission to Hospital**
#
# Min - 1 Day
#
# Max - 28 Days
#
# Mean - 8 Days
#
# **CRP Upon Admission**
#
# Min - 1.0
#
# Max - 328.0
#
# Mean - 95.0
#
# **Noraml Value:  Less Than 10**
#
# **INR Upon Admission**
#
# Min - 0.98
#
# Max - 1.92
#
# Mean - 1.27
#
# **Normal Value: 1.1 or Below**
#
# **PT Upon Admission**
#
# Min - 10.7
#
# Max - 20.6
#
# Mean - 13.9
#
# **Normal Range:  11 to 12.5 Seconds for Clotting**
#
# **Fibrinogen Upon Admission**
#
# Min - 1.24
#
# Max - 11.28
#
# Mean - 4.89
#
# **Normal Range: 2.0 to 4.0**
#
# **Admit Chest CT Percentage Affected**
#
# Min - 10%
#
# Max - 92%
#
# Mean - 51.28%
#
# **Platelet Count**
#
# Min - 38
#
# Max - 493
#
# Mean - 181.35
#
# **Noraml Range:  150 to 450**
#
# **Chest CT Percent Affected Post Treatment by 7 Days**
#
# Min - 0%
#
# Max - 100%
#
# Mean - Nearly 36%
#
# **CRP Post Treatment by 7 Days**
#
# Min - 0
#
# Max - 323
#
# Mean - 64
#
# **Normal Value:  Less Than 10**

# %% [markdown]
# Next, let's see if we can do a Correlation Matrix on our two datasets.

# %%
# Correlation Matrix on the "covid" Dataset
corr = covid.corr()
f, ax = plt.subplots(figsize=(25, 25))
sns.heatmap(corr, square=True, cbar=True, annot=True, fmt='.3f',
            xticklabels=True, yticklabels=True,
            cmap="coolwarm", linewidth=1, ax=ax)
plt.title('COVID FEATURE CORRELATION - HEATMAP', size=17);

# %% [markdown]
# So, what does this heatmap have to say about our data? We can see that Labored Breathing, Coughing, Temp above 103, Obesity, Smoking, and Age over 60 Yrs all play a significant role in the possibility of an indivdual requiring ICU transfer and ventilation.  Secondary consideration is the percentage of Lung Tissue obstructed along with related blood abnormalities.

# %%
corr = stats_subset.corr()
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corr, square=True, cbar=True, annot=True, fmt='.3f',
            xticklabels=True, yticklabels=True,
            cmap="coolwarm", linewidth=1, ax=ax)
plt.title('COVID FEATURE SUBSET - HEATMAP', size=20);

# %% [markdown]
# Next, I have included a simple pair plot using seaborn.  This allows us to see some of the distribution patterns of our data points.

# %%
sns.pairplot(stats_subset)

# %% [markdown]
# Next, let's load addtional analytic features for our modeling tasks.

# %%
import time
import warnings
import itertools
import numpy as np
import pydotplus
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.externals.six import StringIO
from sklearn import tree
import scipy.stats as stats
from pandas import set_option
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.decomposition import PCA
import scipy
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.decomposition import PCA
import warnings

# %% [markdown]
# Next, let's take a quick look at the number of patients requiring ventilation.

# %%
vent_chart = covid['VENTILATION YES/NO'].value_counts()
vent_chart = vent_chart[:7,]
plt.figure(figsize=(15,5))
sns.barplot(vent_chart.index, vent_chart.values, alpha=0.5)
plt.title('VENTILATION REQUIREMENT BAR CHART')
plt.ylabel('Patiient Number')
plt.xlabel('Ventilation Requirement')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# So, of our 350 Patients 226 required Ventilation after transfer to the ICU.

# %% [markdown]
# Based on my Proposal Letter from Module One I will be performing three different modeling blocks. BLOCK ONE:  Ventilation Vs. Pusle OX, Chest Scan, Labored Breathing, and 72 Hrs ICU Transfer. BLOCK TWO:  Ventilation Vs. the Blood Markers. BLOCK THREE:  Ventilation Vs. 7 Selected key features; Chest CT w/Greater than 25% Obstruction, Pulse OX below 88%, Age - 60 Yrs, No Loss of Taste or Smell, Transfer to ICU, Abnormal CRP and Labored Breathing.

# %%
# Initially, Let's create the Dataset Slice that will model Ventilation Vs. Pulse Ox, Labored breathing, Transfer to ICU and Chest CT
lung_covid = covid[['VENTILATION BINARY','CHEST CT GREATER 25 PERCENT BINARY','ADMIT LABORED BREATHING BINARY','PULSE OX BELOW 88','SMOKER BINARY','COUGH BINARY']]
lung_covid.head(5)
# Out:
#    VENTILATION BINARY  ...  COUGH BINARY
# 0                   0  ...             1
# 1                   1  ...             0
# 2                   1  ...             0
# 3                   1  ...             1
# 4                   1  ...             0
#
# [5 rows x 6 columns]

# %% [markdown]
# Ok, now we can begin the initally modeling with BLOCK ONE (LUNG FUNCTIONS) by using TRAIN TEST SPLIT.

# %%
# This will split the "LUNG_COVID" subset into training (75%) and testing (25%) sets.
X = lung_covid.drop('VENTILATION BINARY', axis=1)
y = lung_covid['VENTILATION BINARY']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, stratify=y, random_state=123)

print('Training Set: ', X_train.shape, y_train.shape)
print('Testing Set: ', X_test.shape, y_test.shape)
# Out:
# Training Set:  (262, 5) (262,)
# Testing Set:  (88, 5) (88,)

# %%
# Let's setup the Hyperparameter Grid for Logistic Regression
param_grid = {'C': np.logspace(-5, 8, 15)}

# Define the Logistic Regression Classifier
logreg = LogisticRegression()

# Define the Randomized Search CV
logreg_cv = RandomizedSearchCV(logreg, param_grid, cv=5, random_state=123)

# Fit it to the Dataset
logreg_cv.fit(X_train, y_train)

# Print the tuned parameters and the score
print("Tuned Logistric Regression Parameters:  {}".format(logreg_cv.best_params_))
# Out:
# Tuned Logistric Regression Parameters:  {'C': 31.622776601683793}

# %% [markdown]
# Ok, we now have our "C" parameter for Logistic Regression (0.052). Next we will run Logistic Regression.

# %%
LR = LogisticRegression(C=31.6, random_state=123)
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
print('Accuary:', metrics.accuracy_score(y_pred, y_test))

## 5-Fold CV
cv_scores = cross_val_score(LR, X, y, cv=5)

# Print the 5-Fold Cross-Val Scores
print()
print(classification_report(y_test, y_pred))
print()
print("Average 5-Fold CV Score: {}".format(round(np.mean(cv_scores),4)),
      ", Standard Deviation: {}".format(round(np.std(cv_scores),4)))

plt.figure(figsize=(4,3))
ConfMatrix = confusion_matrix(y_test,LR.predict(X_test))
sns.heatmap(ConfMatrix, annot=True, cmap="Blues", fmt='d',
            xticklabels = ['VENTILATION NO', 'VENTILATION YES'],
            yticklabels = ['VENTILATION NO', 'VENTILATION YES'])

plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title("Confusion Matrix - Logistic Regression/Patient Ventilation Requirement");
# Out:
# Accuary: 0.6590909090909091
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.10      0.17        31
#            1       0.66      0.96      0.79        57
#
#     accuracy                           0.66        88
#    macro avg       0.63      0.53      0.48        88
# weighted avg       0.64      0.66      0.57        88
#
#
# Average 5-Fold CV Score: 0.6114 , Standard Deviation: 0.0305

# %% [markdown]
# Next, the Decision Tree Classifier

# %%
# Let's run a Decision Tree Classifier
dtc = DecisionTreeClassifier(criterion='entropy', max_depth=5).fit(X_train, y_train)
dtc

DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
                       max_depth=5, max_features=None, max_leaf_nodes=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, presort='deprecated',
                       random_state=123, splitter='best')


## 5-Fold Cross-Validation
cv_scores = cross_val_score(dtc, X, y, cv=5)

# Print the 5-Fold Cross Validation Scores
print()
print(classification_report(y_test, y_pred))
print()
print("Average 5-Fold CV Score: {}".format(round(np.mean(cv_scores),4)),
      ", Standard Deviation: {}".format(round(np.std(cv_scores),4)))

plt.figure(figsize=(4,3))
ConfMatrix = confusion_matrix(y_test,dtc.predict(X_test))
sns.heatmap(ConfMatrix, annot=True, cmap="Blues", fmt='d',
            xticklabels = ['VENTILATION NO', 'VENTILATION YES'],
            yticklabels = ['VENTILATION NO', 'VENTILATION YES'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title("Confusion Matrix - Decision Tree/Patient Ventilation Requirement")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.10      0.17        31
#            1       0.66      0.96      0.79        57
#
#     accuracy                           0.66        88
#    macro avg       0.63      0.53      0.48        88
# weighted avg       0.64      0.66      0.57        88
#
#
# Average 5-Fold CV Score: 0.62 , Standard Deviation: 0.0483
# Text(0.5, 1.0, 'Confusion Matrix - Decision Tree/Patient Ventilation Requirement')

# %%
# Let's see the Accuracy Evaluation for the DT
yhat = dtc.predict(X_test)
print('Training Set Accuracy: ', metrics.accuracy_score(y_train, dtc.predict(X_train)))
print('Test Set Accuracy: ', metrics.accuracy_score(y_test, yhat))
# Out:
# Training Set Accuracy:  0.6717557251908397
# Test Set Accuracy:  0.6590909090909091

# %% [markdown]
# Finally, we will run a Random Forest Classifier against the "lung_covid" sub slice.

# %%
rfc = RandomForestClassifier(criterion='entropy', max_depth=7).fit(X_train, y_train)
yhatRF = rfc.predict(X_test)
print('Training Set Accuracy:', metrics.accuracy_score(y_train, rfc.predict(X_train)))
print('Testing Set Accuracy: ', metrics.accuracy_score(y_test, yhatRF))
# Out:
# Training Set Accuracy: 0.6717557251908397
# Testing Set Accuracy:  0.6590909090909091

# %%
# RFC with Grid Search and Cross Validation.
rfc_params = {'n_estimators':[2,5,10,20,50,75,150],
              'criterion':['gini', 'entropy'],
              'max_depth':[2,5,10,20,50,None],
              'min_samples_split':[2,5,10,20]}

grid_rfc = GridSearchCV(RandomForestClassifier(),
                        rfc_params,
                        cv=5,
                        scoring='accuracy').fit(X_train, y_train)

yhatGS = grid_rfc.predict(X_test)

print('Training Set Accuracy:', metrics.accuracy_score(y_train, grid_rfc.predict(X_train)))
print('Testing Set Accuracy:', metrics.accuracy_score(y_test, yhatGS))
# Out:
# Training Set Accuracy: 0.6717557251908397
# Testing Set Accuracy: 0.6590909090909091

# %% [markdown]
# Next, we will run 5 Fold Cross Validation and print out the Confusion Matrix for Random Forest.

# %%
## 5-Fold Cross Validation
cv_scores = cross_val_score(rfc, X, y, cv=5)

# Print the 5-Fold Cross Validation Scores
print()
print(classification_report(y_test, y_pred))
print()
print("Average 5-Fold CV Scores: {}".format(round(np.mean(cv_scores),4)),
      ", Standard Deviation: {}".format(round(np.std(cv_scores),4)))
plt.figure(figsize=(4,3))
ConfMatrix = confusion_matrix(y_test,rfc.predict(X_test))
sns.heatmap(ConfMatrix, annot=True, cmap="Blues", fmt='d',
            xticklabels = ['VENTILATION NO', 'VENTILATION YES'],
            yticklabels = ['VENTILATION NO', 'VENTILATION YES'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title("Confusion Matrix/Random Forest - Patient Ventilation Requirement");
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.10      0.17        31
#            1       0.66      0.96      0.79        57
#
#     accuracy                           0.66        88
#    macro avg       0.63      0.53      0.48        88
# weighted avg       0.64      0.66      0.57        88
#
#
# Average 5-Fold CV Scores: 0.6143 , Standard Deviation: 0.0535

# %% [markdown]
# Next, I will plot an Eval ROC Graph comparing the 3 Classifiers.

# %%
y_pred_proba_RF = rfc.predict_proba(X_test)[::,1]
fpr1, tpr1, _ = metrics.roc_curve(y_test, y_pred_proba_RF)
auc1 = metrics.roc_auc_score(y_test, y_pred_proba_RF)

y_pred_proba_DT = dtc.predict_proba(X_test)[::,1]
fpr2, tpr2, _ = metrics.roc_curve(y_test, y_pred_proba_DT)
auc2 = metrics.roc_auc_score(y_test, y_pred_proba_DT)

y_pred_proba_LR = LR.predict_proba(X_test)[::,1]
fpr3, tpr3, _ = metrics.roc_curve(y_test, y_pred_proba_RF)
auc3 = metrics.roc_auc_score(y_test, y_pred_proba_LR)

plt.figure(figsize=(10,7))
plt.plot([0,1], [0,1], 'k--')
plt.plot(fpr1,tpr1,label="Random Forest, auc="+str(round(auc1,2)))
plt.plot(fpr2,tpr2,label="Decision Tree, auc="+str(round(auc2,2)))
plt.plot(fpr3,tpr3,label="Logistic Regression, auc="+str(round(auc3,2)))
plt.legend(loc=4, title='Models', facecolor='white')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC GRAPH - PATIENT VENTILATION REQUIREMENT VS. LUNG FUNCTIONS')
plt.box(True)
plt.savefig('ImageName', format='png', dpi=200, transparent=False);

# %% [markdown]
# Next, let's do some quick comparisions between different Classifiers.

# %%
modelRFC = RandomForestClassifier(n_estimators=1000, min_samples_split=10, criterion='gini')
modelRFC.fit(X_train, y_train)

modelETC = ExtraTreesClassifier(n_estimators=1000, min_samples_split=10)
modelETC.fit(X_train, y_train)

modelDTC = DecisionTreeClassifier()
modelDTC.fit(X_train, y_train)

modelKNN = KNeighborsClassifier()
modelKNN.fit(X_train, y_train)

modelLR = LogisticRegression()
modelLR.fit(X_train, y_train)

scoreRFC = modelRFC.score(X_test, y_test)
scoreETC = modelETC.score(X_test, y_test)
scoreDTC = modelDTC.score(X_test, y_test)
scoreKNN = modelKNN.score(X_test, y_test)
scoreLR = modelLR.score(X_test, y_test)

print('Random Forest', scoreRFC)
print('Extra Tree Classifier', scoreETC)
print('Decision Tree', scoreDTC)
print('KNN', scoreKNN)
print('Logistic Regression', scoreLR)
# Out:
# Random Forest 0.6590909090909091
# Extra Tree Classifier 0.6590909090909091
# Decision Tree 0.6590909090909091
# KNN 0.6477272727272727
# Logistic Regression 0.6590909090909091

# %% [markdown]
# Let's Graph this so we can take it in with a quick look.

# %%
pd.DataFrame([("Decision Tree", scoreDTC),
              ("Random Forest", scoreRFC),
              ("Extra Tree Classifier", scoreETC),
              ("KNN", scoreKNN),
              ("Logistic Regression", scoreLR),],
              columns=["Model", "score"]).plot(x="Model", y="score", kind="barh", fontsize=12)
plt.xlabel('Score', fontsize=12)
plt.ylabel('Model', fontsize=12)
# Out:
# Text(0, 0.5, 'Model')
